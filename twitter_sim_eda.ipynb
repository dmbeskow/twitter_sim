# %%
# !pip install --user .

# %%
import twitter_sim
all_beliefs,total_tweets, G = twitter_sim.run(size = 100, 
                                  perc_bots = 0.12, 
                                  strategy = 'normal', 
                                  polarized = 'polarized')
# Out:
# 100% (1680 of 1680) |####################| Elapsed Time: 0:03:51 Time:  0:03:51

# %%
# %matplotlib inline
twitter_sim.draw_simulation(G)

# %%
twitter_sim.draw_tweet_timeline(total_tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0c6f84dc3c29> in <module>
# ----> 1 twitter_sim.draw_tweet_timeline(total_tweets)
#
# ~\OneDrive\CMU\Classes\Simulation\project\twitter_sim\twitter_sim\__init__.py in draw_tweet_timeline(t_tweets, plot_type)
#     359     '''
#     360     import matplotlib.pyplot as plt
# --> 361     df = pd.concat(total_tweets)
#     362     df['type'] = 'noise'
#     363     df.loc[df['tweets'] != 0,['type']] = 'disinformation'
#
# NameError: name 'total_tweets' is not defined

# %%
twitter_sim.draw_tweet_bar(total_tweets)

# %%
twitter_sim.draw_beliefs(all_beliefs)
